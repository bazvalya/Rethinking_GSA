# %%
import os
import os.path
import pickle
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
from mycolorpy import colorlist as mcp

import proplot as pplt

from SALib.analyze import sobol

# Plotting parameters
mpl.rcParams["figure.dpi"] = 100
mpl.rcParams["legend.fontsize"] = 12.5
mpl.rcParams["font.size"] = 13.5
mpl.rcParams["axes.grid"] = True
mpl.rcParams["grid.alpha"] = 0.1
mpl.rcParams["axes.axisbelow"] = True
mpl.rcParams["figure.figsize"] = (6, 4)
mpl.rcParams['axes.labelsize'] = 15
mpl.rcParams['axes.titlesize'] = 15

pplt.rc['grid.linewidth'] = 0.1
pplt.rc['grid.alpha'] = 0.3

USE_TEX = False

if USE_TEX:
    plt.rc("text", usetex=True)
    plt.rc("text.latex", preamble=r"""
     \usepackage{times}
     \usepackage{mathptmx}""")
else:
    plt.rc("text", usetex=False)
    
plt.rc("font", family="serif")

# %%
samples       = np.asarray(range(1024*7))
response_vars = ['SUSCEPTIBLE', 'HOSPITALIZED', 'DEATH', 'RECOVERED', 'ACTIVE']

num_steps     = 180
num_runs      = 20
num_responses = len(response_vars)
num_samples   = len(samples)

# %% [markdown]
# ## Writing data file .pickle from the original data found at https://figshare.com/articles/dataset/output_data_zip/22216921

# %%
# # Declaring path to data 
# path='output_data'

# # Renamaming folders in the dir to uq_no_interventions{sample_id}
# # Use once 

# for folder_name in os.listdir(path):
#     if 'uq_no_interventions' in folder_name:
#         os.rename(os.path.join(path, folder_name), 
#                   os.path.join(path, '_'.join(folder_name.split('_')[1:])))

# # Printing first 5 files in the directory
# print(os.listdir(path)[:5])

# %%
# # Creating all results array:

# results_all = np.zeros((num_runs, num_samples, num_responses, num_steps))

# for run in range(num_runs):
#     for s in samples:
#         df = pd.read_csv(os.path.join(path, 
#                                       f'uq_no_interventions{s}/{run}_agents_stages_summary_seed_1234.csv'))
#         for response_ind, response in enumerate(response_vars):
#             results_all[run, s, response_ind, :] = df[response].to_numpy().ravel()

# %%
if not os.path.exists('data/data_DeepABM/results_all_array.pickle'):
    with open('data/data_DeepABM/results_all_array.pickle', 'wb') as f:
        pickle.dump(results_all, f)    
else:
    with open('data/data_DeepABM/results_all_array.pickle', 'rb') as f:
        results_all = pickle.load(f)

# %%
print(results_all.shape)
# Out:
# (20, 7168, 5, 180)

# %% [markdown]
# # GSA on DeepABM-COVID19 using SALib

# %%
problem = {
  'num_vars': 5, 
  'names': ['R', 
            'SFSusceptibility_Scalar', 
            'SFInfector_Scalar', 
            'B_n_Scalar',
            'lam_gamma_Scalar'],
  'bounds': [[1.9, 6.5], 
             [0.5, 1.5],
             [0.5, 1.5], 
             [0.7, 1.3],
             [0.7, 1.3]]
}

param_names_short = {'R': r'$R$',
            'SFSusceptibility_Scalar': r'$S_F$', 
            'SFInfector_Scalar': r'$A_F$',
            'B_n_Scalar': r'$B_F$',
            'lam_gamma_Scalar': r'$\Gamma_F$', 
}

# %%
timesteps = np.linspace(24, num_steps-6, 6, dtype=int)
print(timesteps)
# Out:
# [ 24  54  84 114 144 174]

# %%
# Combining results into 7168*20 by 5 responses with reshape
results_combined_ts = {}

for ts in timesteps: 
    results_combined_ts[ts] = results_all[:, :, :, ts].reshape(7168*20, 5)

Si_all_combined_ts ={}
for ts in timesteps:
    Si_all_combined = {}
    for i, res in enumerate(response_vars):
        
        print(' ')
        print('Time step:', ts)
        print('Model output:', res)
        Si_all_combined[res] = sobol.analyze(problem, 
                                             results_combined_ts[ts][:,i], 
                                             calc_second_order=False, 
                                             print_to_console=True, 
                                             seed=546)
    Si_all_combined_ts[ts] = Si_all_combined
# Out:
#
# Time step: 24
# Model output: SUSCEPTIBLE
#                                ST   ST_conf
# R                        0.706343  0.055918
# SFSusceptibility_Scalar  0.638624  0.057837
# SFInfector_Scalar        0.692261  0.079580
# B_n_Scalar               0.400600  0.060114
# lam_gamma_Scalar         0.547560  0.078192
#                                S1   S1_conf
# R                        0.052939  0.005564
# SFSusceptibility_Scalar  0.060173  0.008891
# SFInfector_Scalar        0.051301  0.008757
# B_n_Scalar               0.018748  0.004569
# lam_gamma_Scalar         0.043644  0.009414
#
# Time step: 24
# Model output: HOSPITALIZED
#                                ST   ST_conf
# R                        0.736765  0.036775
# SFSusceptibility_Scalar  0.711405  0.038808
# SFInfector_Scalar        0.724194  0.048204
# B_n_Scalar               0.589677  0.047527
# lam_gamma_Scalar         0.638009  0.038591
#                                S1   S1_conf
# R                        0.075280  0.013525
# SFSusceptibility_Scalar  0.064299  0.011672
# SFInfector_Scalar        0.065471  0.014822
# B_n_Scalar               0.030163  0.013296
# lam_gamma_Scalar         0.048025  0.012971
#
# Time step: 24
# Model output: DEATH
#                                ST   ST_conf
# R                        0.898733  0.036157
# SFSusceptibility_Scalar  0.878903  0.031735
# SFInfector_Scalar        0.888449  0.033140
# B_n_Scalar               0.863712  0.031612
# lam_gamma_Scalar         0.876752  0.031871
#                                S1   S1_conf
# R                        0.019179  0.018166
# SFSusceptibility_Scalar  0.026671  0.016141
# SFInfector_Scalar        0.017914  0.016613
# B_n_Scalar               0.002214  0.016380
# lam_gamma_Scalar         0.011683  0.020148
#
# Time step: 24
# Model output: RECOVERED
#                                ST   ST_conf
# R                        0.641377  0.047903
# SFSusceptibility_Scalar  0.580352  0.049574
# SFInfector_Scalar        0.615972  0.061633
# B_n_Scalar               0.376265  0.051316
# lam_gamma_Scalar         0.512405  0.058083
#                                S1   S1_conf
# R                        0.088794  0.008544
# SFSusceptibility_Scalar  0.087466  0.011220
# SFInfector_Scalar        0.077218  0.009605
# B_n_Scalar               0.034934  0.006905
# lam_gamma_Scalar         0.063672  0.011883
#
# Time step: 24
# Model output: ACTIVE
#                                ST   ST_conf
# R                        0.713374  0.056757
# SFSusceptibility_Scalar  0.644918  0.058603
# SFInfector_Scalar        0.700617  0.081451
# B_n_Scalar               0.403997  0.061104
# lam_gamma_Scalar         0.551565  0.080249
#                                S1   S1_conf
# R                        0.049128  0.005247
# SFSusceptibility_Scalar  0.057115  0.008591
# SFInfector_Scalar        0.048502  0.008637
# B_n_Scalar               0.016992  0.004333
# lam_gamma_Scalar         0.041428  0.009093
#
# Time step: 54
# Model output: SUSCEPTIBLE
#                                ST   ST_conf
# R                        0.446064  0.012108
# SFSusceptibility_Scalar  0.388095  0.013126
# SFInfector_Scalar        0.388622  0.012014
# B_n_Scalar               0.163955  0.005982
# lam_gamma_Scalar         0.120233  0.004572
#                                S1   S1_conf
# R                        0.213147  0.011948
# SFSusceptibility_Scalar  0.172421  0.011053
# SFInfector_Scalar        0.158049  0.011783
# B_n_Scalar               0.061230  0.007419
# lam_gamma_Scalar         0.036672  0.005430
#
# Time step: 54
# Model output: HOSPITALIZED
#                                ST   ST_conf
# R                        0.662450  0.016576
# SFSusceptibility_Scalar  0.595051  0.018715
# SFInfector_Scalar        0.577950  0.017343
# B_n_Scalar               0.336645  0.011406
# lam_gamma_Scalar         0.319131  0.011355
#                                S1   S1_conf
# R                        0.153915  0.014892
# SFSusceptibility_Scalar  0.130901  0.013055
# SFInfector_Scalar        0.115475  0.015014
# B_n_Scalar               0.041622  0.011837
# lam_gamma_Scalar         0.038891  0.010569
#
# Time step: 54
# Model output: DEATH
#                                ST   ST_conf
# R                        0.445675  0.015321
# SFSusceptibility_Scalar  0.394300  0.017874
# SFInfector_Scalar        0.422283  0.016536
# B_n_Scalar               0.205392  0.008796
# lam_gamma_Scalar         0.216870  0.010191
#                                S1   S1_conf
# R                        0.168296  0.014481
# SFSusceptibility_Scalar  0.138032  0.012158
# SFInfector_Scalar        0.121186  0.011401
# B_n_Scalar               0.069611  0.009021
# lam_gamma_Scalar         0.059452  0.010270
#
# Time step: 54
# Model output: RECOVERED
#                                ST   ST_conf
# R                        0.439976  0.013663
# SFSusceptibility_Scalar  0.384624  0.014629
# SFInfector_Scalar        0.400286  0.013621
# B_n_Scalar               0.175356  0.006871
# lam_gamma_Scalar         0.161655  0.006749
#                                S1   S1_conf
# R                        0.191939  0.013253
# SFSusceptibility_Scalar  0.153900  0.011386
# SFInfector_Scalar        0.135000  0.010472
# B_n_Scalar               0.070708  0.007776
# lam_gamma_Scalar         0.046952  0.007267
#
# Time step: 54
# Model output: ACTIVE
#                                ST   ST_conf
# R                        0.653065  0.015124
# SFSusceptibility_Scalar  0.659037  0.017152
# SFInfector_Scalar        0.634544  0.016681
# B_n_Scalar               0.403046  0.011159
# lam_gamma_Scalar         0.345122  0.011335
#                                S1   S1_conf
# R                        0.125137  0.016365
# SFSusceptibility_Scalar  0.085249  0.015928
# SFInfector_Scalar        0.104548  0.015558
# B_n_Scalar               0.004034  0.013087
# lam_gamma_Scalar         0.002232  0.011914
#
# Time step: 84
# Model output: SUSCEPTIBLE
#                                ST   ST_conf
# R                        0.422438  0.007910
# SFSusceptibility_Scalar  0.376601  0.010484
# SFInfector_Scalar        0.366114  0.008531
# B_n_Scalar               0.163874  0.005080
# lam_gamma_Scalar         0.075892  0.002808
#                                S1   S1_conf
# R                        0.285203  0.011816
# SFSusceptibility_Scalar  0.223703  0.011525
# SFInfector_Scalar        0.232090  0.012901
# B_n_Scalar               0.057692  0.008036
# lam_gamma_Scalar         0.020968  0.004548
#
# Time step: 84
# Model output: HOSPITALIZED
#                                ST   ST_conf
# R                        0.893495  0.020409
# SFSusceptibility_Scalar  0.836835  0.019347
# SFInfector_Scalar        0.837203  0.017425
# B_n_Scalar               0.648219  0.018582
# lam_gamma_Scalar         0.469089  0.017326
#                                S1   S1_conf
# R                       -0.033842  0.020091
# SFSusceptibility_Scalar  0.038261  0.020385
# SFInfector_Scalar       -0.033787  0.016805
# B_n_Scalar              -0.048917  0.013280
# lam_gamma_Scalar        -0.009912  0.013787
#
# Time step: 84
# Model output: DEATH
#                                ST   ST_conf
# R                        0.438722  0.008471
# SFSusceptibility_Scalar  0.397398  0.011555
# SFInfector_Scalar        0.385343  0.009962
# B_n_Scalar               0.172969  0.004713
# lam_gamma_Scalar         0.098156  0.003177
#                                S1   S1_conf
# R                        0.264075  0.011755
# SFSusceptibility_Scalar  0.202113  0.011852
# SFInfector_Scalar        0.218895  0.013882
# B_n_Scalar               0.057595  0.008265
# lam_gamma_Scalar         0.031029  0.005297
#
# Time step: 84
# Model output: RECOVERED
#                                ST   ST_conf
# R                        0.425261  0.008218
# SFSusceptibility_Scalar  0.379655  0.011041
# SFInfector_Scalar        0.369101  0.009112
# B_n_Scalar               0.160881  0.004628
# lam_gamma_Scalar         0.081226  0.002773
#                                S1   S1_conf
# R                        0.276405  0.011650
# SFSusceptibility_Scalar  0.213310  0.011522
# SFInfector_Scalar        0.227435  0.013229
# B_n_Scalar               0.060070  0.008005
# lam_gamma_Scalar         0.026188  0.004801
#
# Time step: 84
# Model output: ACTIVE
#                                ST   ST_conf
# R                        0.925624  0.023306
# SFSusceptibility_Scalar  0.866370  0.020255
# SFInfector_Scalar        0.843351  0.017654
# B_n_Scalar               0.641850  0.017367
# lam_gamma_Scalar         0.478535  0.016448
#                                S1   S1_conf
# R                       -0.049097  0.019125
# SFSusceptibility_Scalar  0.028032  0.019669
# SFInfector_Scalar       -0.051654  0.019119
# B_n_Scalar              -0.048685  0.015207
# lam_gamma_Scalar        -0.009039  0.013323
#
# Time step: 114
# Model output: SUSCEPTIBLE
#                                ST   ST_conf
# R                        0.419806  0.008374
# SFSusceptibility_Scalar  0.370512  0.009161
# SFInfector_Scalar        0.358375  0.008183
# B_n_Scalar               0.162249  0.005481
# lam_gamma_Scalar         0.063217  0.002643
#                                S1   S1_conf
# R                        0.288559  0.012151
# SFSusceptibility_Scalar  0.238792  0.011418
# SFInfector_Scalar        0.231100  0.012153
# B_n_Scalar               0.056142  0.007149
# lam_gamma_Scalar         0.011568  0.004667
#
# Time step: 114
# Model output: HOSPITALIZED
#                                ST   ST_conf
# R                        0.962295  0.029170
# SFSusceptibility_Scalar  0.898574  0.030919
# SFInfector_Scalar        0.906312  0.030321
# B_n_Scalar               0.716028  0.023059
# lam_gamma_Scalar         0.575996  0.022750
#                                S1   S1_conf
# R                        0.035669  0.017994
# SFSusceptibility_Scalar  0.012850  0.017089
# SFInfector_Scalar        0.011137  0.015817
# B_n_Scalar              -0.008011  0.016284
# lam_gamma_Scalar         0.026245  0.016229
#
# Time step: 114
# Model output: DEATH
#                                ST   ST_conf
# R                        0.440390  0.008591
# SFSusceptibility_Scalar  0.396490  0.009937
# SFInfector_Scalar        0.384060  0.008596
# B_n_Scalar               0.184729  0.006107
# lam_gamma_Scalar         0.081947  0.003194
#                                S1   S1_conf
# R                        0.278031  0.012472
# SFSusceptibility_Scalar  0.229937  0.011666
# SFInfector_Scalar        0.219702  0.012987
# B_n_Scalar               0.048473  0.008014
# lam_gamma_Scalar         0.012787  0.005010
#
# Time step: 114
# Model output: RECOVERED
#                                ST   ST_conf
# R                        0.418597  0.008193
# SFSusceptibility_Scalar  0.371642  0.009361
# SFInfector_Scalar        0.359851  0.008078
# B_n_Scalar               0.163445  0.005445
# lam_gamma_Scalar         0.064804  0.002600
#                                S1   S1_conf
# R                        0.288609  0.012089
# SFSusceptibility_Scalar  0.237455  0.011335
# SFInfector_Scalar        0.231088  0.012281
# B_n_Scalar               0.055103  0.007385
# lam_gamma_Scalar         0.011720  0.004608
#
# Time step: 114
# Model output: ACTIVE
#                                ST   ST_conf
# R                        0.959484  0.031072
# SFSusceptibility_Scalar  0.898621  0.030924
# SFInfector_Scalar        0.900790  0.032188
# B_n_Scalar               0.730150  0.025770
# lam_gamma_Scalar         0.588831  0.024613
#                                S1   S1_conf
# R                        0.039099  0.019033
# SFSusceptibility_Scalar  0.014021  0.017535
# SFInfector_Scalar        0.018051  0.016886
# B_n_Scalar              -0.006647  0.017619
# lam_gamma_Scalar         0.024886  0.015930
#
# Time step: 144
# Model output: SUSCEPTIBLE
#                                ST   ST_conf
# R                        0.426428  0.009297
# SFSusceptibility_Scalar  0.364093  0.009062
# SFInfector_Scalar        0.350783  0.008561
# B_n_Scalar               0.158666  0.005488
# lam_gamma_Scalar         0.061965  0.003070
#                                S1   S1_conf
# R                        0.288909  0.012401
# SFSusceptibility_Scalar  0.241374  0.012231
# SFInfector_Scalar        0.233994  0.011826
# B_n_Scalar               0.059657  0.006807
# lam_gamma_Scalar         0.012882  0.004791
#
# Time step: 144
# Model output: HOSPITALIZED
#                                ST   ST_conf
# R                        0.937702  0.036917
# SFSusceptibility_Scalar  0.941819  0.039679
# SFInfector_Scalar        0.921600  0.035412
# B_n_Scalar               0.825332  0.036841
# lam_gamma_Scalar         0.659474  0.034294
#                                S1   S1_conf
# R                        0.023386  0.019560
# SFSusceptibility_Scalar  0.020009  0.017951
# SFInfector_Scalar        0.001852  0.019411
# B_n_Scalar              -0.010804  0.016917
# lam_gamma_Scalar         0.005883  0.016067
#
# Time step: 144
# Model output: DEATH
#                                ST   ST_conf
# R                        0.454144  0.009892
# SFSusceptibility_Scalar  0.395419  0.009809
# SFInfector_Scalar        0.381883  0.009602
# B_n_Scalar               0.183250  0.006257
# lam_gamma_Scalar         0.079996  0.003609
#                                S1   S1_conf
# R                        0.273133  0.013011
# SFSusceptibility_Scalar  0.230511  0.012426
# SFInfector_Scalar        0.217091  0.012552
# B_n_Scalar               0.052136  0.007493
# lam_gamma_Scalar         0.012587  0.005385
#
# Time step: 144
# Model output: RECOVERED
#                                ST   ST_conf
# R                        0.424670  0.009068
# SFSusceptibility_Scalar  0.365214  0.009010
# SFInfector_Scalar        0.352159  0.008496
# B_n_Scalar               0.158870  0.005472
# lam_gamma_Scalar         0.061664  0.002951
#                                S1   S1_conf
# R                        0.289147  0.012349
# SFSusceptibility_Scalar  0.241267  0.012035
# SFInfector_Scalar        0.233423  0.011888
# B_n_Scalar               0.059340  0.006864
# lam_gamma_Scalar         0.012697  0.004741
#
# Time step: 144
# Model output: ACTIVE
#                                ST   ST_conf
# R                        0.918050  0.037687
# SFSusceptibility_Scalar  0.924762  0.038673
# SFInfector_Scalar        0.905305  0.035776
# B_n_Scalar               0.811639  0.038235
# lam_gamma_Scalar         0.646009  0.035457
#                                S1   S1_conf
# R                        0.024127  0.017822
# SFSusceptibility_Scalar  0.019171  0.017008
# SFInfector_Scalar       -0.005323  0.019859
# B_n_Scalar              -0.011855  0.015926
# lam_gamma_Scalar         0.005603  0.016074
#
# Time step: 174
# Model output: SUSCEPTIBLE
#                                ST   ST_conf
# R                        0.429489  0.009882
# SFSusceptibility_Scalar  0.361064  0.009251
# SFInfector_Scalar        0.346577  0.008496
# B_n_Scalar               0.158457  0.005522
# lam_gamma_Scalar         0.063593  0.003375
#                                S1   S1_conf
# R                        0.287691  0.012464
# SFSusceptibility_Scalar  0.239874  0.012679
# SFInfector_Scalar        0.235365  0.011759
# B_n_Scalar               0.058626  0.006591
# lam_gamma_Scalar         0.012547  0.005002
#
# Time step: 174
# Model output: HOSPITALIZED
#                                ST   ST_conf
# R                        0.845231  0.035806
# SFSusceptibility_Scalar  0.889227  0.042225
# SFInfector_Scalar        0.878869  0.042774
# B_n_Scalar               0.832235  0.048244
# lam_gamma_Scalar         0.704173  0.038351
#                                S1   S1_conf
# R                        0.023202  0.018937
# SFSusceptibility_Scalar  0.013951  0.016174
# SFInfector_Scalar       -0.006411  0.017153
# B_n_Scalar               0.016591  0.017872
# lam_gamma_Scalar         0.002616  0.015013
#
# Time step: 174
# Model output: DEATH
#                                ST   ST_conf
# R                        0.463763  0.011031
# SFSusceptibility_Scalar  0.393776  0.010249
# SFInfector_Scalar        0.378548  0.009926
# B_n_Scalar               0.185165  0.006429
# lam_gamma_Scalar         0.083750  0.004194
#                                S1   S1_conf
# R                        0.269266  0.013168
# SFSusceptibility_Scalar  0.227879  0.013244
# SFInfector_Scalar        0.217255  0.012346
# B_n_Scalar               0.051660  0.007233
# lam_gamma_Scalar         0.012988  0.005784
#
# Time step: 174
# Model output: RECOVERED
#                                ST   ST_conf
# R                        0.428859  0.009774
# SFSusceptibility_Scalar  0.361342  0.009202
# SFInfector_Scalar        0.347151  0.008525
# B_n_Scalar               0.158232  0.005507
# lam_gamma_Scalar         0.062956  0.003322
#                                S1   S1_conf
# R                        0.288081  0.012447
# SFSusceptibility_Scalar  0.240493  0.012607
# SFInfector_Scalar        0.235302  0.011739
# B_n_Scalar               0.059119  0.006633
# lam_gamma_Scalar         0.012726  0.004948
#
# Time step: 174
# Model output: ACTIVE
#                                ST   ST_conf
# R                        0.847121  0.036314
# SFSusceptibility_Scalar  0.892592  0.040808
# SFInfector_Scalar        0.884083  0.043060
# B_n_Scalar               0.826674  0.047687
# lam_gamma_Scalar         0.700544  0.040401
#                                S1   S1_conf
# R                        0.030979  0.018351
# SFSusceptibility_Scalar  0.020227  0.016147
# SFInfector_Scalar       -0.001992  0.016393
# B_n_Scalar               0.025269  0.018177
# lam_gamma_Scalar         0.006743  0.014799

# %%
pplt.rc['grid.linewidth'] = 0.5
pplt.rc['grid.alpha'] = 0.3

error_marker_styles = ['d', 'X','o', 'v', 'P', 's', '*']
colors=mcp.gen_color(cmap="Dark2",n=9)

fig, axs = pplt.subplots(ncols=2, nrows=5, figsize=(11, 14), sharex=True, sharey=False)

col1 = np.linspace(0, 8, 5, dtype='int')
col2 = np.linspace(1, 9, 5, dtype='int')

titles = [var.title() for i, var in enumerate(response_vars)]

for res_ind, res in enumerate(response_vars):
    ls = []
    for i, param in enumerate(problem['names']):
        S1_at_ts = [Si_all_combined_ts[ts][res]['S1'][i] for ts in timesteps]
        S1_errors   = [Si_all_combined_ts[ts][res]['S1_conf'][i] for ts in timesteps]

        ST_at_ts = [Si_all_combined_ts[ts][res]['ST'][i] for ts in timesteps]
        ST_errors   = [Si_all_combined_ts[ts][res]['ST_conf'][i] for ts in timesteps]

        l = axs[col1[res_ind]].scatter(timesteps, S1_at_ts, color=colors[i],
                                       label=param_names_short[param], edgecolor='k', 
                                       marker=error_marker_styles[i], 
                                       markersize=80, zorder=3)       
        axs[col1[res_ind]].errorbar(timesteps, S1_at_ts, S1_errors, color=colors[i],
                                    markeredgewidth=1.5, linestyle='--', 
                                    capsize=7, alpha=1, elinewidth=1.2)  
        axs[col1[res_ind]].format(ylim=(-0.08, 0.32))
        axs[col1[res_ind]].set_title(titles[res_ind])
        axs[col1[res_ind]].set_ylabel(r'$S_{i}$', labelpad=30) 
        
        axs[col2[res_ind]].scatter(timesteps, ST_at_ts, color=colors[i],
                                   label=param_names_short[param], edgecolor='k', 
                                   marker=error_marker_styles[i], 
                                   markersize=80, zorder=3)       
        axs[col2[res_ind]].errorbar(timesteps, ST_at_ts, ST_errors, color=colors[i],
                                    markeredgewidth=1.5, linestyle='--', 
                                    capsize=7, alpha=1, elinewidth=1.2) 
        axs[col2[res_ind]].format(ylim=(-0, 1.05))
        axs[col2[res_ind]].set_ylabel(r'$S_{T_i}$', labelpad=30) 
        axs[col2[res_ind]].set_title(titles[res_ind])
        
        ls.append(l)

axs.format(abc='(a)', xlabel='Time steps')

axs.format(rc_kw={'title.size': 19,
                  'label.size': 19,
                  'tick.labelsize': 14,
                  'leftlabel.size': 17})

for i, ax in enumerate(axs):
    ax.yaxis.label.set(rotation='horizontal', ha='left')

fig.legend(ls, param_names_short.values(), ncols=5, frame=True, loc='t', bbox_to_anchor=(0.5, -1), 
           fontsize=16, title="Uncertain parameters:", title_fontsize=18)

plt.savefig('plots/appendix/DeepABM_SALib_ts.pdf', bbox_inches='tight')
plt.show()
# Out:
# Figure(nrows=5, ncols=2, figwidth=11.0, figheight=14.0)
